# %%
import xarray as xr
import numpy as np
from error_predictor import BiasPredictor
import matplotlib.pyplot as plt

# %%
# Just testing
xr_data=xr.load_dataset("results_stacked_hh.nc")

# # Creating an instance of the BiasPredictor class
predictor = BiasPredictor(xr_data)

# Running the predictor
cv_df, best_model = predictor.run()
# Out:
# Preprocessing the data...
# Running dimension reduction... currently a placeholder
# Finding best model and hyperparameters, training the model...
# Cross-validation metrics saved to 'cv_metrics.csv'

# %%
# Best hyperparameters... being fit to the whole dataset
best_model
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, device=None,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None,
#                               learning_rate=0.05977351479421033, max_bin=None,
#                               max_cat_threshold=None, max_cat_to_onehot=None,
#                               max_delta_step=None, max_depth=4, max_leaves=None,
# ...

# %%
X,y=predictor.preprocess_data()

# %%
X_demo=X.iloc[500:1000] 
y_demo=y.iloc[500:1000]

y_pred=best_model.predict(X_demo)

plt.plot(y_demo.values, label='True')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()
