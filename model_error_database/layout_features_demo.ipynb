# %%
from utils import blockage_metrics
import numpy as np
import matplotlib.pyplot as plt

# %%
xy = np.array([
    [0.0,   0.0],
    [300.0, 0.0],
    [600.0,0.0],
    [0.0,   240.0],
    [300.0, 240.0],
    [600.0,240.0],
])  # meters; say D = 120 m
x=np.array([0,300,600,0,300,600])
y=np.array([0,0,0,240,240,240])
np.column_stack((x, y))
D = 120.0
wind_dir = 100  # wind FROM west (flow toward east)

BR, BD, BR_farm, BD_farm = blockage_metrics(xy, wind_dir, D,plot=True)

plt.plot(BR)
